# %%
#we may need some code in the ../python directory and/or matplotlib styles
import sys
sys.path.append('../python/')

#matplotlib for plotting
import matplotlib as mpl
from matplotlib import pyplot as plt
plt.style.use('mplstyles/stylelib/standard.mplstyle')

#other computational libraries
import numpy as np

# %%
#define x1 and x2
x1=0
x2=1
y1=0
y2=1

# %%
def q(y,a,b):
    return a*y**2 + b

def t(y,a,b):
    return a*y**3 + b

# %%
A1 = np.array([[y1,1],[y2,1]])
A2 = np.array([[y1**2,1],[y2**2,1]])

B = np.array([x1,x2])

C1 = np.linalg.solve(A1,B)
C2 = np.linalg.solve(A2,B)

print(C1)
print(C2)
# Out:
# [1. 0.]
# [1. 0.]

# %%
#set up a 1d plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0),sharex=True)
ax1 = axes



ax1.plot(t,guess(t,A=1.7,B=4,C=0,omega=1.45),color='g',linestyle="-",linewidth=2, \
         label='spring')

ax1.plot(t,x,color='orange',linestyle="-",linewidth=2, \
         label='spring')
ax1.plot(t,v,color='r',linestyle="-",linewidth=2, \
         label='')


ax1.set_yscale('linear')
#ax1.set_yscale('log')
ax1.set_xlim(0, 40) 
ax1.set_ylim(-10,10)
ax1.set_xlabel(r'x-Time [s]')
ax1.set_ylabel('y-Distance [m]')
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':12})
#ax1.legend(bbox_to_anchor=(1.04,1),borderaxespad=0,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
#plt.savefig('figures/figure.png')
plt.show()
